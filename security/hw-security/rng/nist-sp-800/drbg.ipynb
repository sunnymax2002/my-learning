# %% [markdown]
# Analysis of NIST SP 800-90A specified DRBG, and (cost, performance) v/s security strength tradeoff of actual implementations
#
# Also analyzes if simpler DRBGs e.g. Xoshiro256++ are a reasonable choice for lightweight cryptographic applications, and extend the study to argue about the choice of RNG in NIST SP 800-232
