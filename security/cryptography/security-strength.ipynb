# %% [markdown]
# Develop the concept of security strength and relation to key lengths, e.g. a contrast between RSA and ECC algorithms. Further, analyze how a brute force attack can be made more efficient through probability concepts like birthday attack (and extent the argument for memory encryption and scrambling algorithm choices)
